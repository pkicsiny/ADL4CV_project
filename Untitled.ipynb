# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import regex

# %%
with open("raa01-rx_10000-1812031730-dwd---bin", "rb") as f:
    byte = f.read()

# %%
byte[:1500]
# Out:
# b"RX031730100001218BY 810142VS 3SW   2.21.0PR E+00INT   5GP 900x 900MS 70<asb,boo,ros,hnr,umd,pro,ess,fld,drs,neu,nhb,oft,eis,tur,isn,fbg,mem> \xf
# ...

# %%
karte = np.flip(np.reshape(np.asarray([c for c in byte[142:]]),(900,900)), axis=0)

# %%
karte = np.flip(np.reshape(np.asarray([c for c in byte[142:]]),(900,900)), axis=0)
karte[karte == 250] = -1
plt.imshow(np.ma.masked_where(karte < 0,karte))
plt.colorbar()

# %%
pat = regex.compile(b"(.*)",byte)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-743c97ec6f70> in <module>()
# ----> 1 pat = regex.compile(b"(.*)",byte)
#
# C:\ProgramData\Anaconda3\lib\site-packages\regex.py in compile(pattern, flags, **kwargs)
#     343 def compile(pattern, flags=0, **kwargs):
#     344     "Compile a regular expression pattern, returning a pattern object."
# --> 345     return _compile(pattern, flags, kwargs)
#     346
#     347 def purge():
#
# C:\ProgramData\Anaconda3\lib\site-packages\regex.py in _compile(pattern, flags, kwargs)
#     434
#     435     # We won't bother to cache the pattern if we're debugging.
# --> 436     debugging = (flags & DEBUG) != 0
#     437
#     438     # What locale is this pattern using?
#
# TypeError: unsupported operand type(s) for &: 'bytes' and 'int'

# %%
byte.I
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-2028828c8fe7> in <module>()
# ----> 1 byte.I
#
# AttributeError: 'bytes' object has no attribute 'I'
